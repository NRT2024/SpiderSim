# %%
import sys
import logging
import gym
import cyberbattle.agents.baseline.learner as learner
import cyberbattle.agents.baseline.plotting as p
import cyberbattle.agents.baseline.agent_wrapper as w
import cyberbattle.agents.baseline.agent_randomcredlookup as rca
import cyberbattle.agents.baseline.agent_tabularqlearning as tqa
import cyberbattle.agents.baseline.agent_dql as dqla
from cyberbattle.agents.baseline.agent_wrapper import Verbosity

logging.basicConfig(stream=sys.stdout, level=logging.ERROR, format="%(levelname)s: %(message)s")

# %%
# Parameters
gymid = "CyberBattleDigital-v0"
iteration_count = 1500
training_episode_count = 20
eval_episode_count = 10
maximum_node_count = 12
maximum_total_credentials = 10
env_size = None

# %%
# Load the Gym environment
if env_size:
    gym_env = gym.make(gymid, size=env_size)
else:
    gym_env = gym.make(gymid)

ep = w.EnvironmentBounds.of_identifiers(
    maximum_node_count=maximum_node_count,
    maximum_total_credentials=maximum_total_credentials,
    identifiers=gym_env.identifiers
)

# %%
debugging = False
if debugging:
    print(f"port_count = {ep.port_count}, property_count = {ep.property_count}")

    gym_env.environment
    # training_env.environment.plot_environment_graph()
    gym_env.environment.network.nodes
    gym_env.action_space
    gym_env.action_space.sample()
    gym_env.observation_space.sample()
    o0 = gym_env.reset()
    o_test, r, d, i = gym_env.step(gym_env.sample_valid_action())
    o0 = gym_env.reset()

    o0.keys()

    fe_example = w.RavelEncoding(ep, [w.Feature_active_node_properties(ep), w.Feature_discovered_node_count(ep)])
    a = w.StateAugmentation(o0)
    w.Feature_discovered_ports(ep).get(a, None)
    fe_example.encode_at(a, 0)

# %%
# Evaluate the Deep Q-learning agent
dql_run = learner.epsilon_greedy_search(
    cyberbattle_gym_env=gym_env,
    environment_properties=ep,
    learner=dqla.DeepQLearnerPolicy(
        ep=ep,
        gamma=0.015,
        replay_memory_size=10000,
        target_update=10,
        batch_size=512,
        # torch default learning rate is 1e-2
        # a large value helps converge in less episodes
        learning_rate=0.01
    ),
    episode_count=training_episode_count,
    iteration_count=iteration_count,
    epsilon=0.90,
    epsilon_exponential_decay=5000,
    epsilon_minimum=0.10,
    verbosity=Verbosity.Quiet,
    render=False,
    plot_episodes_length=False,
    title="DQL"
)
# Out:
# ###### DQL
# Learning with: episode_count=20,iteration_count=1500,ϵ=0.9,ϵ_min=0.1, ϵ_expdecay=5000,γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=10
#   ## Episode: 1/20 'DQL' ϵ=0.9000, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=10
# Episode 1|Iteration 0|reward: ------|last_reward_at: ----|Elapsed Time: 0:00:00||/home/ubuntu/CyberBattleSim/cyberbattle/agents/baseline/agent_dql.py:382: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:230.)
#   state_batch = torch.tensor(states_to_consider).to(device)
# Episode 1|Iteration 617|reward: -2030.0|last_reward_at:  452|Elapsed Time: 0:00:04||
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Evaluate the Deep Q-learning agent
# ----> 2 dql_run = learner.epsilon_greedy_search(
#       3     cyberbattle_gym_env=gym_env,
#       4     environment_properties=ep,
#       5     learner=dqla.DeepQLearnerPolicy(
#       6         ep=ep,
#       7         gamma=0.015,
#       8         replay_memory_size=10000,
#       9         target_update=10,
#      10         batch_size=512,
#      11         # torch default learning rate is 1e-2
#      12         # a large value helps converge in less episodes
#      13         learning_rate=0.01
#      14     ),
#      15     episode_count=training_episode_count,
#      16     iteration_count=iteration_count,
#      17     epsilon=0.90,
#      18     epsilon_exponential_decay=5000,
#      19     epsilon_minimum=0.10,
#      20     verbosity=Verbosity.Quiet,
#      21     render=False,
#      22     plot_episodes_length=False,
#      23     title="DQL"
#      24 )
#
# File /home/ubuntu/CyberBattleSim/cyberbattle/agents/baseline/learner.py:269, in epsilon_greedy_search(cyberbattle_gym_env, environment_properties, learner, title, episode_count, iteration_count, epsilon, epsilon_minimum, epsilon_multdecay, epsilon_exponential_decay, render, render_last_episode_rewards_to, verbosity, plot_episodes_length)
#     267 # Take the step
#     268 logging.debug(f"gym_action={gym_action}, action_metadata={action_metadata}")
# --> 269 observation, reward, done, info = wrapped_env.step(gym_action)
#     271 action_type = 'exploit' if action_style == 'exploit' else 'explore'
#     272 outcome = 'reward' if reward > 0 else 'noreward'
#
# File /home/ubuntu/CyberBattleSim/cyberbattle/agents/baseline/agent_wrapper.py:525, in AgentWrapper.step(self, action)
#     524 def step(self, action: cyberbattle_env.Action):
# --> 525     observation, reward, done, info = self.env.step(action)
#     526     self.state.on_step(action, reward, done, observation)
#     527     return observation, reward, done, info
#
# File /usr/local/lib/python3.9/dist-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       9 def step(self, action):
#      10     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11     observation, reward, done, info = self.env.step(action)
#      12     return observation, reward, done, info
#
# File /home/ubuntu/CyberBattleSim/cyberbattle/_env/cyberbattle_env.py:1105, in CyberBattleEnv.step(self, action)
#    1103 try:
#    1104     result = self.__execute_action(action)
# -> 1105     observation, reward = self.__observation_reward_from_action_result(result)
#    1107     # Execute the defender step if provided
#    1108     if self.__defender_agent:
#
# File /home/ubuntu/CyberBattleSim/cyberbattle/_env/cyberbattle_env.py:901, in CyberBattleEnv.__observation_reward_from_action_result(self, result)
#     898 obs['_discovered_nodes'] = self.__discovered_nodes
#     899 obs['_explored_network'] = self.__get_explored_network()
# --> 901 self.__update_action_mask(obs['action_mask'])
#     902 return obs, result.reward
#
# File /home/ubuntu/CyberBattleSim/cyberbattle/_env/cyberbattle_env.py:657, in CyberBattleEnv.__update_action_mask(self, bitmask)
#     651 bitmask["remote_vulnerability"][source_index,
#     652                                 target_index,
#     653                                 :remote_vulnerabilities_count] = 1
#     655 # the agent may attempt to connect to any port
#     656 # and use any credential from its cache (though it's not guaranteed to succeed)
# --> 657 bitmask["connect"][source_index,
#     658                    target_index,
#     659                    :port_count,
#     660                    :len(self.__credential_cache)] = 1
#
# KeyboardInterrupt:

# %%
# Evaluate the random agent
random_run = learner.epsilon_greedy_search(
    gym_env,
    ep,
    learner=learner.RandomPolicy(),
    episode_count=eval_episode_count,
    iteration_count=iteration_count,
    epsilon=1.0,  # purely random
    render=False,
    verbosity=Verbosity.Quiet,
    plot_episodes_length=False,
    title="Random search"
)
# Out:
# ###### Random search
# Learning with: episode_count=10,iteration_count=1500,ϵ=1.0,ϵ_min=0.0,
#   ## Episode: 1/10 'Random search' ϵ=1.0000,
# Episode 1|Iteration 1500|reward: -6040.0|last_reward_at: 1311|Elapsed Time: 0:00:03||
#   Episode 1 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/228 (0.00)
#     explore-remote: 8/615 (0.01)
#     explore-connect: 4/644 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 2/10 'Random search' ϵ=1.0000,
# Episode 2|Iteration 1500|reward: -5929.0|last_reward_at: 1361|Elapsed Time: 0:00:03||
#   Episode 2 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/228 (0.00)
#     explore-remote: 8/627 (0.01)
#     explore-connect: 4/632 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 3/10 'Random search' ϵ=1.0000,
# Episode 3|Iteration 1500|reward: -6210.0|last_reward_at:  262|Elapsed Time: 0:00:04||
#   Episode 3 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/156 (0.01)
#     explore-remote: 8/680 (0.01)
#     explore-connect: 4/651 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 4/10 'Random search' ϵ=1.0000,
# Episode 4|Iteration 1500|reward: -6167.0|last_reward_at:  975|Elapsed Time: 0:00:03||
#   Episode 4 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/171 (0.01)
#     explore-remote: 8/667 (0.01)
#     explore-connect: 4/649 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 5/10 'Random search' ϵ=1.0000,
# Episode 5|Iteration 1500|reward: -6045.0|last_reward_at:  612|Elapsed Time: 0:00:04||
#   Episode 5 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/180 (0.01)
#     explore-remote: 8/662 (0.01)
#     explore-connect: 4/645 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 6/10 'Random search' ϵ=1.0000,
# Episode 6|Iteration 1500|reward: -5942.0|last_reward_at:  928|Elapsed Time: 0:00:03||
#   Episode 6 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/211 (0.00)
#     explore-remote: 8/645 (0.01)
#     explore-connect: 4/631 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 7/10 'Random search' ϵ=1.0000,
# Episode 7|Iteration 1500|reward: -6509.0|last_reward_at:  638|Elapsed Time: 0:00:03||
#   Episode 7 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/233 (0.00)
#     explore-remote: 8/614 (0.01)
#     explore-connect: 3/641 (0.00)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 8/10 'Random search' ϵ=1.0000,
# Episode 8|Iteration 1500|reward: -6195.0|last_reward_at:  885|Elapsed Time: 0:00:03||
#   Episode 8 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/184 (0.01)
#     explore-remote: 8/631 (0.01)
#     explore-connect: 4/672 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 9/10 'Random search' ϵ=1.0000,
# Episode 9|Iteration 1500|reward: -6330.0|last_reward_at:  589|Elapsed Time: 0:00:04||
#   Episode 9 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/168 (0.01)
#     explore-remote: 8/635 (0.01)
#     explore-connect: 4/684 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 10/10 'Random search' ϵ=1.0000,
# Episode 10|Iteration 1500|reward: -6294.0|last_reward_at:  303|Elapsed Time: 0:00:04||
#   Episode 10 stopped at t=1500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/159 (0.01)
#     explore-remote: 8/653 (0.01)
#     explore-connect: 4/675 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
# simulation ended

# %%
# Compare and plot results for all the agents
all_runs = [
    random_run,
    dql_run,
]

# Plot averaged cumulative rewards for DQL vs Random vs DQL-Exploit
themodel = dqla.CyberBattleStateActionModel(ep)
p.plot_averaged_cummulative_rewards(
    all_runs=all_runs,
    title=f"Rewards accumulated by attackers with different learning methods")
